# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(
    model ="qwen2.5:3b ",
    temperature=0.3
)

# %%
res = llm.invoke("what is the weather of jabalpur taday?")
res
# Out:
# AIMessage(content="I'm sorry, but I don't have real-time or specific historical weather data for every single location and time point available. To get the current or specific past weather conditions in Jabalpur, you can use a variety of weather forecasting websites, apps, or services such as AccuWeather, The Weather Channel, or local news channels that provide weather updates.\n\nFor up-to-date information on the current weather in Jabalpur, I recommend checking one of these sources. They will be able to give you accurate and reliable data based on their latest observations and forecasts.", additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b ', 'created_at': '2026-08-10T07:15:16.0093443Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8880254800, 'load_duration': 460115500, 'prompt_eval_count': 40, 'prompt_eval_duration': 391403000, 'eval_count': 114, 'eval_duration': 7999516000, 'logprobs': None, 'model_name': 'qwen2.5:3b ', 'model_provider': 'ollama'}, id='lc_ru
# ...
