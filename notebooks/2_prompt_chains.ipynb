# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(
    model = "qwen2.5:3b",
    temperature = 0.3
)

# %%
prompts = [
    {
        'role':'system','content':'you are a translator and translate input to japnies'
    },
    {
        'role':'user',
        'content':'i like taylor swift songs'
    }
]

# %%
res = llm.invoke(prompts)
res.content
# Out:
# '私はターレル・スウィフトの歌が好きです。'

# %% [markdown]
# #### prompt templates - dynamic prompts

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOllama(
    model='qwen2.5:3b',
    temperature = 0.3
)

# %%
prompts = ChatPromptTemplate.from_template(
    """you are a helpful assisstant which helps to explain {topic} in easy language don't use complex terminologies"""
)

# %%
parser = StrOutputParser()

# %%
chain = prompts|llm|parser

# %%
res = chain.invoke({
    "topic":"RAG"
})

# %%
res
# Out:
# 'Sure! Imagine you have a big book of stories and another book with questions about those stories.\n\nRAG stands for "Retrieval-Augmented Generation." It\'s like when you\'re trying to answer a question, but instead of just using your own knowledge, you also look up information in other books or sources. \n\nHere’s how it works:\n1. You have a system that can understand and generate text (like answering questions).\n2. This system is trained on lots of different texts.\n3. When someone asks a question, the system tries to find answers directly from its training data first.\n4. If the system doesn’t find an exact answer, it looks for helpful information in other places (like your big book of stories).\n5. It then combines this new information with what it already knows and generates a response.\n\nSo, RAG is like having a super smart helper who not only remembers everything but also can look up more details when needed to give the best answer possible!'
