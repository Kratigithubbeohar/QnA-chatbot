# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
documents = [
    "I have a class of genAI on Monday",
    "Go for a haircut",
    "Complete AI Task Manager"
]

# %%
from langchain_ollama import OllamaEmbeddings

# %%
embeddings = OllamaEmbeddings(model = "nomic-embed-text:latest")

# %%
vector = embeddings.embed_documents(documents)

# %%
len(vector[0])
# Out:
# 768

# %% [markdown]
# #### storing this vector embedding into vector database

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_texts(
    texts = documents,
    embedding = embeddings,
    persist_directory = "./vector_db"
)

# %%
query = 'haircut'
result = vector_store.similarity_search(query=query)
result
# Out:
# [Document(id='f78c280f-953b-4201-9b7c-9d320d006786', metadata={}, page_content='Go for a haircut'),
#  Document(id='87edad7b-14ea-45e8-b0eb-73c59c10dcd4', metadata={}, page_content='I have a class on Monday'),
#  Document(id='343bfb3e-762d-4ec1-9f39-eb5cb680ef20', metadata={}, page_content='Complete AI Task Manager')]
