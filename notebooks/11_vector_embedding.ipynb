# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
documents = [
    "I have a class of genAI on Monday",
    "Go for a haircut",
    "Complete AI Task Manager"
]

# %%
from langchain_ollama import OllamaEmbeddings

# %%
embeddings = OllamaEmbeddings(model = "nomic-embed-text:latest")

# %%
vector = embeddings.embed_documents(documents)

# %%
len(vector[0])
# Out:
# 768

# %% [markdown]
# #### storing this vector embedding into vector database

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_texts(
    texts = documents,
    embedding = embeddings,
    persist_directory = "./vector_db"
)

# %%
query = 'AI'
result = vector_store.similarity_search(query=query)
result
# Out:
# [Document(id='343bfb3e-762d-4ec1-9f39-eb5cb680ef20', metadata={}, page_content='Complete AI Task Manager'),
#  Document(id='000b434a-e84d-47d2-b8d0-38e3037b4ce8', metadata={}, page_content='Complete AI Task Manager'),
#  Document(id='43a91618-41e1-4dfa-a980-19c3be195dde', metadata={}, page_content='Complete AI Task Manager'),
#  Document(id='215eb490-3b24-493b-bd6e-0cbabf914cff', metadata={'source': '../data/kratiresume_ai.pdf', 'total_pages': 1, 'creator': 'LaTeX with hyperref', 'page': 0, 'subject': '', 'moddate': '2026-08-11T04:08:35+00:00', 'keywords': '', 'author': '', 'page_label': '1', 'title': '', 'creationdate': '2026-08-11T04:08:35+00:00', 'trapped': '/False', 'producer': 'pdfTeX-1.40.27', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1'}, page_content='and Generative AI. Seeking an entry-')]
