# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text = "Then the installed wikipedia package may not be passing the user agent correctly through its internal calls. In that case, don't keep fighting the old package—we can switch to wikipedia-api, which explicitly supports a user_agent parameter. Its documentation requires a project-identifying user agent."

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 50, chunk_overlap = 20)

# %%
chunks = splitter.split_text(text)

# %%
chunks
# Out:
# ['Then the installed wikipedia package may not be',
#  'package may not be passing the user agent',
#  'the user agent correctly through its internal',
#  "its internal calls. In that case, don't keep",
#  "case, don't keep fighting the old package—we can",
#  'old package—we can switch to wikipedia-api, which',
#  'which explicitly supports a user_agent parameter.',
#  'parameter. Its documentation requires a',
#  'requires a project-identifying user agent.']

# %% [markdown]
# #### document text loader

# %%
from langchain_community.document_loaders import TextLoader, PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# C:\Users\krati\AppData\Local\Temp\ipykernel_31256\2006942201.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader, PyPDFLoader

# %%
 loader = TextLoader("../data/speech.txt")
 text = loader.load()

# %%
pdfLoader = PyPDFLoader("../data/kratiresume_ai.pdf")
pdfs = pdfLoader.load()

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 200)

# %%
chunks = splitter.split_documents(text)
len(chunks)
# Out:
# 1

# %%
chunks
# Out:
# [Document(metadata={'source': '../data/speech.txt'}, page_content='page_content = """Models are the reasoning engine of agents. They drive the agentâ€™s decision-making process, determining which tools to call, how to interpret results, and when to provide a final answer.\nThe quality and capabilities of the model you choose directly impact your agentâ€™s baseline reliability and performance. Different models excel at different tasks - some are better at following complex instructions, others at structured reasoning, and some support larger context windows for handling more information.\nLangChainâ€™s standard model interfaces give you access to many different provider integrations, which makes it easy to experiment with and switch between models to find the best fit for your use case.\nFor provider-specific integra"""')]

# %%
pdf_chunks = splitter.split_documents(pdfs)
len(pdf_chunks)
# Out:
# 3

# %%
pdf_chunks
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-08-11T04:08:35+00:00', 'author': '', 'keywords': '', 'moddate': '2026-08-11T04:08:35+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': '../data/kratiresume_ai.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='KRATI BEOHAR\n+91-9691549355⋄Hyderabad, Telangana, India, 500049\nkratibeohar@gmail.com⋄Linkedin⋄GitHub\nOBJECTIVE\nComputer Science graduate with a strong foundation in Data Structures and Algorithms, C++, Python, and software\ndevelopment, with hands-on experience in FastAPI, React.js, REST APIs, MongoDB, and Generative AI. Seeking an entry-\nlevel Software Engineer position to develop scalable solutions, apply technical expertise, and contribute to organizational\nobjectives.\nEDUCA TION\nGyan Ganga Institute of T echnology & Sci
# ...
